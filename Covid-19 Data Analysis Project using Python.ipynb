# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
VACCINE_DATA = pd.read_csv("C:/Users/Motso/Documents/HEX DATA SCIENCE INTERNSHIP TASKS/TASK 3/VACCINE_DATA.csv")
day_wise = pd.read_csv("C:/Users/Motso/Documents/HEX DATA SCIENCE INTERNSHIP TASKS/TASK 3/day_wise.csv")

# %%
VACCINE_DATA.columns
# Out:
# Index(['AGE_YRS', 'DATEDIED', 'VAX_DATE', 'NUMDAYS'], dtype='object')

# %%
VACCINE_DATA.head()
# Out:
#    AGE_YRS    DATEDIED    VAX_DATE  NUMDAYS
# 0        5  11/22/2021  11/18/2021        4
# 1        5   9/20/2022  11/22/2021      302
# 2        7  12/10/2021  11/29/2021       11
# 3        8    5/3/2022  12/28/2021      126
# 4        9    6/3/2022   12/4/2021      181

# %%
VACCINE_DATA.isnull().sum()
# Out:
# AGE_YRS     0
# DATEDIED    0
# VAX_DATE    0
# NUMDAYS     0
# dtype: int64

# %%
VACCINE_DATA.nunique()
# Out:
# AGE_YRS      100
# DATEDIED    1009
# VAX_DATE     393
# NUMDAYS      893
# dtype: int64

# %%
sb.histplot(data = VACCINE_DATA, x = 'AGE_YRS', bins = 10, kde = True)
plt.show()

# %%
day_wise.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
day_wise.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
day_wise = day_wise.drop(['Deaths','Recovered','Date', 'Confirmed', 'Deaths / 100 Cases','Active','Recovered / 100 Cases', 'Deaths / 100 Recovered'],axis = 1)

# %%
day_wise.corr()
# Out:
#                   New cases  New deaths  New recovered  No. of countries
# New cases          1.000000    0.721846       0.928570          0.722150
# New deaths         0.721846    1.000000       0.555759          0.835157
# New recovered      0.928570    0.555759       1.000000          0.570745
# No. of countries   0.722150    0.835157       0.570745          1.000000

# %%
sb.heatmap(day_wise.corr(),annot = True)
# Out:
# <Axes: >

# %%
sb.pairplot(data = day_wise,vars = ['New cases',
       'New deaths', 'New recovered'])
plt.show()
